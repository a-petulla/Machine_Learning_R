# %% [markdown]
# # Machine Learning in R

# %% [markdown]
# Reading in the necessary libraries

# %%
library(ggplot2)
library(lattice)
library(caret)
library(ellipse)
library(kernlab)
library(randomForest)

# %% [markdown]
# Reading in the iris data into the environment

# %%
# attach the iris dataset to the environment
data(iris)
# rename the dataset
dataset <- iris

# %% [markdown]
# Loading the iris data into a variable

# %%
# define the filename
filename <- "iris.csv"
# load the CSV file from the local directory
dataset <- read.csv(filename, header=FALSE)
# set the column names in the dataset
colnames(dataset) <- c("Sepal.Length","Sepal.Width","Petal.Length","Petal.Width","Species")

# %% [markdown]
# Creating the test and train datasets

# %%
# create a list of 80% of the rows in the original dataset we can use for training
validation_index <- createDataPartition(dataset$Species, p=0.80, list=FALSE)
# select 20% of the data for validation
validation <- dataset[-validation_index,]
# use the remaining 80% of data to training and testing the models
dataset <- dataset[validation_index,]

# %% [markdown]
# Getting the dimensions of the dataset

# %%
# dimensions of dataset
dim(dataset)
# Out:
# [1] 120   5

# %% [markdown]
# Changing the Species column from a character to a factor

# %%
# Change the Species from a character to a factor
dataset$Species <- as.factor(dataset$Species)
# Out:
# Sepal.Length  Sepal.Width Petal.Length  Petal.Width      Species
#    "numeric"    "numeric"    "numeric"    "numeric"     "factor"

# %% [markdown]
# Getting the types of each column

# %%
# list types for each attribute
sapply(dataset, class)

# %% [markdown]
# Visualizing the first 5 rows in the dataset

# %%
# take a peek at the first 5 rows of the data
head(dataset)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 2 4.9          3.0         1.4          0.2         Iris-setosa
# 3 4.7          3.2         1.3          0.2         Iris-setosa
# 4 4.6          3.1         1.5          0.2         Iris-setosa
# 5 5.0          3.6         1.4          0.2         Iris-setosa
# 6 5.4          3.9         1.7          0.4         Iris-setosa
# 8 5.0          3.4         1.5          0.2         Iris-setosa

# %% [markdown]
# Listing the values in the Species column

# %%
# list the levels for the class
levels(dataset$Species)
# Out:
# [1] "Iris-setosa"     "Iris-versicolor" "Iris-virginica"

# %% [markdown]
# Summarizing each group of the Species column

# %%
# summarize the class distribution
percentage <- prop.table(table(dataset$Species)) * 100
cbind(freq=table(dataset$Species), percentage=percentage)
# Out:
#                 freq percentage
# Iris-setosa     40   33.33333
# Iris-versicolor 40   33.33333
# Iris-virginica  40   33.33333

# %% [markdown]
# Summarizing the dataset features

# %%
# summarize attribute distributions
summary(dataset)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.10
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.30
#  Median :5.800   Median :3.000   Median :4.200   Median :1.30
#  Mean   :5.837   Mean   :3.048   Mean   :3.757   Mean   :1.19
#  3rd Qu.:6.425   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.80
#  Max.   :7.900   Max.   :4.400   Max.   :6.700   Max.   :2.50
#             Species
#  Iris-setosa    :40
#  Iris-versicolor:40
#  Iris-virginica :40

# %% [markdown]
# Splitting the features from the predictor column

# %%
# split input and output
x <- dataset[,1:4]
y <- dataset[,5]

# %% [markdown]
# Visualizing the data as a boxplot

# %%
# boxplot for each attribute on one image
par(mfrow=c(1,4))
  for(i in 1:4) {
  boxplot(x[,i], main=names(iris)[i])
}
# Out:
# Plot with title “Petal.Width”

# %% [markdown]
# Visualizing the data as a barplot

# %%
# barplot for class breakdown
plot(y)
# Out:
# plot without title

# %% [markdown]
# Visualizing the data as a scatterplot matrix

# %%
# scatterplot matrix
featurePlot(x=x, y=y, plot="ellipse")
# Out:
# plot without title

# %% [markdown]
# Visualizing the data as a box and whisker plot

# %%
# box and whisker plots for each attribute
featurePlot(x=x, y=y, plot="box")
# Out:
# plot without title

# %% [markdown]
# visualizing the dataset as a density plot

# %%
# density plots for each attribute by class value
scales <- list(x=list(relation="free"), y=list(relation="free"))
featurePlot(x=x, y=y, plot="density", scales=scales)
# Out:
# plot without title

# %% [markdown]
# Run potential models

# %%
# Run algorithms using 10-fold cross validation
control <- trainControl(method="cv", number=10)
metric <- "Accuracy"

# %%
# a) linear algorithms
set.seed(7)
fit.lda <- train(Species~., data=dataset, method="lda", metric=metric, trControl=control)
# b) nonlinear algorithms
# CART
set.seed(7)
fit.cart <- train(Species~., data=dataset, method="rpart", metric=metric, trControl=control)
# kNN
set.seed(7)
fit.knn <- train(Species~., data=dataset, method="knn", metric=metric, trControl=control)
# c) advanced algorithms
# SVM
set.seed(7)
fit.svm <- train(Species~., data=dataset, method="svmRadial", metric=metric, trControl=control)
# Random Forest
set.seed(7)
fit.rf <- train(Species~., data=dataset, method="rf", metric=metric, trControl=control)
# Out:
# Error: Required packages are missing: randomForest
# Traceback:
#
# 1. train(Species ~ ., data = dataset, method = "rf", metric = metric,
#  .     trControl = control)
# 2. train.formula(Species ~ ., data = dataset, method = "rf", metric = metric,
#  .     trControl = control)
# 3. train(x, y, weights = w, ...)
# 4. train.default(x, y, weights = w, ...)
# 5. checkInstall(models$library)
# 6. stop("Required packages are missing: ", pkList, call. = FALSE)

# %% [markdown]
# Summarizing the models

# %%
# summarize accuracy of models
results <- resamples(list(lda=fit.lda, cart=fit.cart, knn=fit.knn, svm=fit.svm, rf=fit.rf))
summary(results)

# %% [markdown]
# Compare the models

# %%
# compare accuracy of models
dotplot(results)

# %% [markdown]
# Summarize the best model

# %%
# summarize Best Model
print(fit.lda)

# %% [markdown]
# Validate the best model on the test set

# %%
# estimate skill of LDA on the validation dataset
predictions <- predict(fit.lda, validation)
confusionMatrix(predictions, validation$Species)
